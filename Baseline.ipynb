# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CS7643\ Deep\ Learning\ Project/RelTR
# Out:
# /content/drive/.shortcut-targets-by-id/1qHoaQqsa_84wKp4XFuiBiBUnxjcdMWJm/CS7643 Deep Learning Project/RelTR

# %%
# !pip install scipy
# !pip install torch==1.6.0 torchvision==0.7.0 cudatoolkit==10.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy) (2.0.2)
# ERROR: Could not find a version that satisfies the requirement torch==1.6.0 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0)
# ERROR: No matching distribution found for torch==1.6.0
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-lnin9qaq
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-lnin9qaq
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (75.2.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (3.0.12)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.17.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp311-cp311-linux_x86_64.whl size=395986 sha256=79e867b35e28ecf89852740c40883bff230a0614ff0c23841e816df810331363
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ekk__xya/wheels/6d/69/75/358c50a37672dfda8d74ba3b30ec49fb75d52f7c081886d503
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.8
#     Uninstalling pycocotools-2.0.8:
#       Successfully uninstalled pycocotools-2.0.8
# Successfully installed pycocotools-2.0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T

from PIL import Image
import requests
import matplotlib.pyplot as plt

# %%
# %cd lib/fpn/box_intersections_cpu
# Out:
# /content/drive/.shortcut-targets-by-id/1qHoaQqsa_84wKp4XFuiBiBUnxjcdMWJm/CS7643 Deep Learning Project/RelTR/lib/fpn/box_intersections_cpu

# %%
# !python setup.py build_ext --inplace

# %% [markdown]
# # Evaluation

# %%
# %cd /content/drive/MyDrive/CS7643\ Deep\ Learning\ Project/RelTR
# !python main.py --dataset vg --img_folder data/vg/images/ --ann_path data/vg/ --eval --batch_size 1 --resume ckpt/checkpoint0149.pth
# Out:
# /content/drive/.shortcut-targets-by-id/1qHoaQqsa_84wKp4XFuiBiBUnxjcdMWJm/CS7643 Deep Learning Project/RelTR
# Not using distributed mode
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(lr=0.0001, lr_backbone=1e-05, batch_size=1, weight_decay=0.0001, epochs=150, lr_drop=100, clip_max_norm=0.1, frozen_weights=None, backbone='resnet50', dilation=False, position_embedding='sine', enc_layers=6, dec_layers=6, dim_feedforward=2048, hidden_dim=256, dropout=0.1, nheads=8, num_entities=100, num_triplets=200, pre_norm=False, aux_loss=True, set_cost_class=1, set_cost_bbox=5, set_cost_giou=2, set_iou_threshold=0.7, bbox_loss_coef=5, giou_loss_coef=2, rel_loss_coef=1, eos_coef=0.1, dataset='vg', ann_path='data/vg/', img_folder='data/vg/images/', output_dir='', device='cuda', seed=42, resume='ckpt/checkpoint0149.pth', start_epoch=0, eval=True, num_workers=2, world_size=1, dist_url='env://', return_interm_layers=False, distributed=False)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 207MB/s]
# number of params: 63679528
# loading annotations into memory...
# Done (t=1.52s)
# creating index...
# index created!
# It is the 149th checkpoint
# Test:  [   0/2919]  eta: 1 day, 1:49:33  class_error: 50.00  sub_error: 33.33  obj_error: 33.33  rel_error: 66.67  loss: 21.6973 (21.6973)  loss_ce: 0.7416 (0.7416)  loss_bbox: 1.1285 (1.1285)  loss_giou: 1.1180 (1.1180)  loss_rel: 0.5675 (0.5675)  loss_ce_0: 0.8705 (0.8705)  loss_bbox_0: 1.2204 (1.2204)  loss_giou_0: 1.1746 (1.1746)  loss_rel_0: 0.4766 (0.4766)  loss_ce_1: 0.7867 (0.7867)  loss_bbox_1: 1.2095 (1.2095)  loss_giou_1: 1.2171 (1.2171)  loss_rel_1: 0.4656 (0.4656)  loss_ce_2: 0.7841 (0.7841)  loss_bbox_2: 1.1281 (1.1281)  loss_giou_2: 1.1987 (1.1987)  loss_rel_2: 0.4994 (0.4994)  loss_ce_3: 0.7592 (0.7592)  loss_bbox_3: 1.1239 (1.1239)  loss_giou_3: 1.1872 (1.1872)  loss_rel_3: 0.5570 (0.5570)  loss_ce_4: 0.7513 (0.7513)  loss_bbox_4: 1.1045 (1.1045)  loss_giou_4: 1.1440 (1.1440)  loss_rel_4: 0.4834 (0.4834)  loss_ce_unscaled: 0.7416 (0.7416)  class_error_unscaled: 50.0000 (50.0000)  sub_error_unscaled: 33.3333 (33.3333)  obj_error_unscaled: 33.3333 (33.3333)  loss_bbox_unscaled: 0.2257 (0.2257)  loss_giou_unscaled: 0.5590 (0.5590)  cardinality_error_unscaled: 12.0000 (12.0000)  loss_rel_unscaled: 0.5675 (0.5675)  rel_error_unscaled: 66.6667 (66.6667)  loss_ce_0_unscaled: 0.8705 (0.8705)  loss_bbox_0_unscaled: 0.2441 (0.2441)  loss_giou_0_unscaled: 0.5873 (0.5873)  cardinality_error_0_unscaled: 11.0000 (11.0000)  loss_rel_0_unscaled: 0.4766 (0.4766)  loss_ce_1_unscaled: 0.7867 (0.7867)  loss_bbox_1_unscaled: 0.2419 (0.2419)  loss_giou_1_unscaled: 0.6085 (0.6085)  cardinality_error_1_unscaled: 14.0000 (14.0000)  loss_rel_1_unscaled: 0.4656 (0.4656)  loss_ce_2_unscaled: 0.7841 (0.7841)  loss_bbox_2_unscaled: 0.2256 (0.2256)  loss_giou_2_unscaled: 0.5993 (0.5993)  cardinality_error_2_unscaled: 16.0000 (16.0000)  loss_rel_2_unscaled: 0.4994 (0.4994)  loss_ce_3_unscaled: 0.7592 (0.7592)  loss_bbox_3_unscaled: 0.2248 (0.2248)  loss_giou_3_unscaled: 0.5936 (0.5936)  cardinality_error_3_unscaled: 10.0000 (10.0000)  loss_rel_3_unscaled: 0.5570 (0.5570)  loss_ce_4_unscaled: 0.7513 (0.7513)  loss_bbox_4_unscaled: 0.2209 (0.2209)  loss_giou_4_unscaled: 0.5720 (0.5720)  cardinality_error_4_unscaled: 11.0000 (11.0000)  loss_rel_4_unscaled: 0.4834 (0.4834)  time: 31.8512  data: 29.8594  max mem: 1214
# Test:  [ 100/2919]  eta: 0:26:05  class_error: 17.39  sub_error: 28.57  obj_error: 28.57  rel_error: 14.29  loss: 17.0983 (19.7330)  loss_ce: 0.4146 (0.4619)  loss_bbox: 0.8296 (0.9788)  loss_giou: 0.9336 (1.0849)  loss_rel: 0.5157 (0.6674)  loss_ce_0: 0.4957 (0.5090)  loss_bbox_0: 0.9230 (1.1019)  loss_giou_0: 1.0189 (1.2418)  loss_rel_0: 0.4907 (0.6545)  loss_ce_1: 0.4503 (0.4819)  loss_bbox_1: 0.7852 (1.0489)  loss_giou_1: 0.9489 (1.1603)  loss_rel_1: 0.5083 (0.6549)  loss_ce_2: 0.4211 (0.4691)  loss_bbox_2: 0.8999 (1.0057)  loss_giou_2: 0.9662 (1.1268)  loss_rel_2: 0.4934 (0.6549)  loss_ce_3: 0.4210 (0.4622)  loss_bbox_3: 0.9227 (1.0020)  loss_giou_3: 0.9666 (1.1146)  loss_rel_3: 0.4624 (0.6528)  loss_ce_4: 0.4150 (0.4625)  loss_bbox_4: 0.8518 (0.9838)  loss_giou_4: 0.9438 (1.0967)  loss_rel_4: 0.5072 (0.6558)  loss_ce_unscaled: 0.4146 (0.4619)  class_error_unscaled: 38.4615 (35.3598)  sub_error_unscaled: 60.0000 (55.2868)  obj_error_unscaled: 57.1429 (52.0286)  loss_bbox_unscaled: 0.1659 (0.1958)  loss_giou_unscaled: 0.4668 (0.5424)  cardinality_error_unscaled: 5.0000 (6.4752)  loss_rel_unscaled: 0.5157 (0.6674)  rel_error_unscaled: 66.6667 (66.4898)  loss_ce_0_unscaled: 0.4957 (0.5090)  loss_bbox_0_unscaled: 0.1846 (0.2204)  loss_giou_0_unscaled: 0.5094 (0.6209)  cardinality_error_0_unscaled: 8.0000 (7.6535)  loss_rel_0_unscaled: 0.4907 (0.6545)  loss_ce_1_unscaled: 0.4503 (0.4819)  loss_bbox_1_unscaled: 0.1570 (0.2098)  loss_giou_1_unscaled: 0.4744 (0.5801)  cardinality_error_1_unscaled: 7.0000 (7.2376)  loss_rel_1_unscaled: 0.5083 (0.6549)  loss_ce_2_unscaled: 0.4211 (0.4691)  loss_bbox_2_unscaled: 0.1800 (0.2011)  loss_giou_2_unscaled: 0.4831 (0.5634)  cardinality_error_2_unscaled: 6.0000 (6.9703)  loss_rel_2_unscaled: 0.4934 (0.6549)  loss_ce_3_unscaled: 0.4210 (0.4622)  loss_bbox_3_unscaled: 0.1845 (0.2004)  loss_giou_3_unscaled: 0.4833 (0.5573)  cardinality_error_3_unscaled: 5.0000 (6.6436)  loss_rel_3_unscaled: 0.4624 (0.6528)  loss_ce_4_unscaled: 0.4150 (0.4625)  loss_bbox_4_unscaled: 0.1704 (0.1968)  loss_giou_4_unscaled: 0.4719 (0.5483)  cardinality_error_4_unscaled: 6.0000 (6.5248)  loss_rel_4_unscaled: 0.5072 (0.6558)  time: 0.2952  data: 0.0898  max mem: 1277
# Test:  [ 200/2919]  eta: 0:17:41  class_error: 16.67  sub_error: 33.33  obj_error: 66.67  rel_error: 66.67  loss: 18.1211 (19.6041)  loss_ce: 0.3256 (0.4615)  loss_bbox: 0.7982 (0.9816)  loss_giou: 0.9911 (1.0689)  loss_rel: 0.5272 (0.6738)  loss_ce_0: 0.3558 (0.5003)  loss_bbox_0: 0.9812 (1.1119)  loss_giou_0: 1.1589 (1.2217)  loss_rel_0: 0.5417 (0.6493)  loss_ce_1: 0.4218 (0.4801)  loss_bbox_1: 0.8288 (1.0469)  loss_giou_1: 1.0855 (1.1314)  loss_rel_1: 0.5648 (0.6507)  loss_ce_2: 0.4116 (0.4682)  loss_bbox_2: 0.8539 (1.0094)  loss_giou_2: 1.0475 (1.1029)  loss_rel_2: 0.5344 (0.6488)  loss_ce_3: 0.3420 (0.4596)  loss_bbox_3: 0.8530 (1.0078)  loss_giou_3: 1.0215 (1.0964)  loss_rel_3: 0.4824 (0.6497)  loss_ce_4: 0.3425 (0.4621)  loss_bbox_4: 0.8098 (0.9874)  loss_giou_4: 1.0237 (1.0750)  loss_rel_4: 0.5150 (0.6589)  loss_ce_unscaled: 0.3256 (0.4615)  class_error_unscaled: 25.0000 (35.5830)  sub_error_unscaled: 57.1429 (57.2547)  obj_error_unscaled: 50.0000 (52.7286)  loss_bbox_unscaled: 0.1596 (0.1963)  loss_giou_unscaled: 0.4955 (0.5344)  cardinality_error_unscaled: 6.0000 (6.2438)  loss_rel_unscaled: 0.5272 (0.6738)  rel_error_unscaled: 66.6667 (67.2717)  loss_ce_0_unscaled: 0.3558 (0.5003)  loss_bbox_0_unscaled: 0.1962 (0.2224)  loss_giou_0_unscaled: 0.5794 (0.6108)  cardinality_error_0_unscaled: 5.0000 (7.0498)  loss_rel_0_unscaled: 0.5417 (0.6493)  loss_ce_1_unscaled: 0.4218 (0.4801)  loss_bbox_1_unscaled: 0.1658 (0.2094)  loss_giou_1_unscaled: 0.5428 (0.5657)  cardinality_error_1_unscaled: 5.0000 (6.9154)  loss_rel_1_unscaled: 0.5648 (0.6507)  loss_ce_2_unscaled: 0.4116 (0.4682)  loss_bbox_2_unscaled: 0.1708 (0.2019)  loss_giou_2_unscaled: 0.5238 (0.5515)  cardinality_error_2_unscaled: 5.0000 (6.4478)  loss_rel_2_unscaled: 0.5344 (0.6488)  loss_ce_3_unscaled: 0.3420 (0.4596)  loss_bbox_3_unscaled: 0.1706 (0.2016)  loss_giou_3_unscaled: 0.5108 (0.5482)  cardinality_error_3_unscaled: 3.0000 (6.3085)  loss_rel_3_unscaled: 0.4824 (0.6497)  loss_ce_4_unscaled: 0.3425 (0.4621)  loss_bbox_4_unscaled: 0.1620 (0.1975)  loss_giou_4_unscaled: 0.5119 (0.5375)  cardinality_error_4_unscaled: 6.0000 (6.1692)  loss_rel_4_unscaled: 0.5150 (0.6589)  time: 0.2230  data: 0.0110  max mem: 1277
# Test:  [ 300/2919]  eta: 0:14:52  class_error: 28.57  sub_error: 0.00  obj_error: 100.00  rel_error: 100.00  loss: 21.1206 (19.9112)  loss_ce: 0.3850 (0.4576)  loss_bbox: 1.3104 (1.0283)  loss_giou: 1.0353 (1.0716)  loss_rel: 0.5446 (0.6865)  loss_ce_0: 0.4315 (0.4965)  loss_bbox_0: 1.2553 (1.1546)  loss_giou_0: 1.1186 (1.2220)  loss_rel_0: 0.5751 (0.6631)  loss_ce_1: 0.4236 (0.4766)  loss_bbox_1: 1.1663 (1.0882)  loss_giou_1: 1.0250 (1.1330)  loss_rel_1: 0.5769 (0.6624)  loss_ce_2: 0.4347 (0.4650)  loss_bbox_2: 1.1014 (1.0519)  loss_giou_2: 1.0354 (1.1066)  loss_rel_2: 0.6364 (0.6611)  loss_ce_3: 0.4156 (0.4586)  loss_bbox_3: 1.1765 (1.0414)  loss_giou_3: 0.9706 (1.0911)  loss_rel_3: 0.6022 (0.6632)  loss_ce_4: 0.4066 (0.4596)  loss_bbox_4: 1.2580 (1.0252)  loss_giou_4: 1.0094 (1.0741)  loss_rel_4: 0.6730 (0.6728)  loss_ce_unscaled: 0.3850 (0.4576)  class_error_unscaled: 28.5714 (34.6812)  sub_error_unscaled: 57.1429 (56.0324)  obj_error_unscaled: 50.0000 (52.9794)  loss_bbox_unscaled: 0.2621 (0.2057)  loss_giou_unscaled: 0.5177 (0.5358)  cardinality_error_unscaled: 6.0000 (6.3787)  loss_rel_unscaled: 0.5446 (0.6865)  rel_error_unscaled: 75.0000 (68.0144)  loss_ce_0_unscaled: 0.4315 (0.4965)  loss_bbox_0_unscaled: 0.2511 (0.2309)  loss_giou_0_unscaled: 0.5593 (0.6110)  cardinality_error_0_unscaled: 5.0000 (7.0565)  loss_rel_0_unscaled: 0.5751 (0.6631)  loss_ce_1_unscaled: 0.4236 (0.4766)  loss_bbox_1_unscaled: 0.2333 (0.2176)  loss_giou_1_unscaled: 0.5125 (0.5665)  cardinality_error_1_unscaled: 4.0000 (6.8372)  loss_rel_1_unscaled: 0.5769 (0.6624)  loss_ce_2_unscaled: 0.4347 (0.4650)  loss_bbox_2_unscaled: 0.2203 (0.2104)  loss_giou_2_unscaled: 0.5177 (0.5533)  cardinality_error_2_unscaled: 5.0000 (6.5183)  loss_rel_2_unscaled: 0.6364 (0.6611)  loss_ce_3_unscaled: 0.4156 (0.4586)  loss_bbox_3_unscaled: 0.2353 (0.2083)  loss_giou_3_unscaled: 0.4853 (0.5455)  cardinality_error_3_unscaled: 5.0000 (6.4784)  loss_rel_3_unscaled: 0.6022 (0.6632)  loss_ce_4_unscaled: 0.4066 (0.4596)  loss_bbox_4_unscaled: 0.2516 (0.2050)  loss_giou_4_unscaled: 0.5047 (0.5371)  cardinality_error_4_unscaled: 6.0000 (6.2060)  loss_rel_4_unscaled: 0.6730 (0.6728)  time: 0.2463  data: 0.0540  max mem: 1284
# Test:  [ 400/2919]  eta: 0:13:04  class_error: 22.22  sub_error: 50.00  obj_error: 0.00  rel_error: 100.00  loss: 17.3902 (19.8319)  loss_ce: 0.3444 (0.4482)  loss_bbox: 0.8401 (1.0315)  loss_giou: 0.9413 (1.0713)  loss_rel: 0.4645 (0.6776)  loss_ce_0: 0.4357 (0.4894)  loss_bbox_0: 1.0041 (1.1534)  loss_giou_0: 1.0356 (1.2206)  loss_rel_0: 0.4111 (0.6589)  loss_ce_1: 0.4001 (0.4682)  loss_bbox_1: 0.8555 (1.0876)  loss_giou_1: 1.0156 (1.1374)  loss_rel_1: 0.4364 (0.6549)  loss_ce_2: 0.3916 (0.4579)  loss_bbox_2: 0.9226 (1.0509)  loss_giou_2: 0.9482 (1.1075)  loss_rel_2: 0.4418 (0.6548)  loss_ce_3: 0.3943 (0.4508)  loss_bbox_3: 0.8477 (1.0402)  loss_giou_3: 0.9312 (1.0911)  loss_rel_3: 0.4197 (0.6585)  loss_ce_4: 0.3876 (0.4512)  loss_bbox_4: 0.8087 (1.0291)  loss_giou_4: 0.9259 (1.0739)  loss_rel_4: 0.4601 (0.6670)  loss_ce_unscaled: 0.3444 (0.4482)  class_error_unscaled: 25.0000 (34.2106)  sub_error_unscaled: 35.2941 (55.4122)  obj_error_unscaled: 41.1765 (53.4472)  loss_bbox_unscaled: 0.1680 (0.2063)  loss_giou_unscaled: 0.4707 (0.5357)  cardinality_error_unscaled: 5.0000 (6.3865)  loss_rel_unscaled: 0.4645 (0.6776)  rel_error_unscaled: 66.6667 (67.8076)  loss_ce_0_unscaled: 0.4357 (0.4894)  loss_bbox_0_unscaled: 0.2008 (0.2307)  loss_giou_0_unscaled: 0.5178 (0.6103)  cardinality_error_0_unscaled: 6.0000 (7.0773)  loss_rel_0_unscaled: 0.4111 (0.6589)  loss_ce_1_unscaled: 0.4001 (0.4682)  loss_bbox_1_unscaled: 0.1711 (0.2175)  loss_giou_1_unscaled: 0.5078 (0.5687)  cardinality_error_1_unscaled: 6.0000 (6.8105)  loss_rel_1_unscaled: 0.4364 (0.6549)  loss_ce_2_unscaled: 0.3916 (0.4579)  loss_bbox_2_unscaled: 0.1845 (0.2102)  loss_giou_2_unscaled: 0.4741 (0.5537)  cardinality_error_2_unscaled: 5.0000 (6.5137)  loss_rel_2_unscaled: 0.4418 (0.6548)  loss_ce_3_unscaled: 0.3943 (0.4508)  loss_bbox_3_unscaled: 0.1695 (0.2080)  loss_giou_3_unscaled: 0.4656 (0.5456)  cardinality_error_3_unscaled: 6.0000 (6.4763)  loss_rel_3_unscaled: 0.4197 (0.6585)  loss_ce_4_unscaled: 0.3876 (0.4512)  loss_bbox_4_unscaled: 0.1617 (0.2058)  loss_giou_4_unscaled: 0.4630 (0.5370)  cardinality_error_4_unscaled: 6.0000 (6.1546)  loss_rel_4_unscaled: 0.4601 (0.6670)  time: 0.1938  data: 0.0189  max mem: 1284
# Test:  [ 500/2919]  eta: 0:11:49  class_error: 25.00  sub_error: 62.50  obj_error: 56.25  rel_error: 37.50  loss: 20.0333 (20.1599)  loss_ce: 0.4522 (0.4554)  loss_bbox: 1.1038 (1.0525)  loss_giou: 1.1566 (1.0866)  loss_rel: 0.6079 (0.6895)  loss_ce_0: 0.5086 (0.4985)  loss_bbox_0: 1.2132 (1.1754)  loss_giou_0: 1.2443 (1.2358)  loss_rel_0: 0.6339 (0.6642)  loss_ce_1: 0.4496 (0.4764)  loss_bbox_1: 1.1580 (1.1118)  loss_giou_1: 1.1909 (1.1558)  loss_rel_1: 0.6559 (0.6599)  loss_ce_2: 0.4578 (0.4662)  loss_bbox_2: 1.1045 (1.0742)  loss_giou_2: 1.1464 (1.1248)  loss_rel_2: 0.6224 (0.6626)  loss_ce_3: 0.4481 (0.4586)  loss_bbox_3: 1.0984 (1.0598)  loss_giou_3: 1.1737 (1.1072)  loss_rel_3: 0.6366 (0.6685)  loss_ce_4: 0.4587 (0.4585)  loss_bbox_4: 1.1100 (1.0501)  loss_giou_4: 1.1455 (1.0892)  loss_rel_4: 0.6050 (0.6784)  loss_ce_unscaled: 0.4522 (0.4554)  class_error_unscaled: 33.3333 (34.9729)  sub_error_unscaled: 57.1429 (56.2214)  obj_error_unscaled: 61.5385 (53.9777)  loss_bbox_unscaled: 0.2208 (0.2105)  loss_giou_unscaled: 0.5783 (0.5433)  cardinality_error_unscaled: 3.0000 (6.3952)  loss_rel_unscaled: 0.6079 (0.6895)  rel_error_unscaled: 66.6667 (68.4477)  loss_ce_0_unscaled: 0.5086 (0.4985)  loss_bbox_0_unscaled: 0.2426 (0.2351)  loss_giou_0_unscaled: 0.6221 (0.6179)  cardinality_error_0_unscaled: 6.0000 (7.1377)  loss_rel_0_unscaled: 0.6339 (0.6642)  loss_ce_1_unscaled: 0.4496 (0.4764)  loss_bbox_1_unscaled: 0.2316 (0.2224)  loss_giou_1_unscaled: 0.5955 (0.5779)  cardinality_error_1_unscaled: 5.0000 (6.7705)  loss_rel_1_unscaled: 0.6559 (0.6599)  loss_ce_2_unscaled: 0.4578 (0.4662)  loss_bbox_2_unscaled: 0.2209 (0.2148)  loss_giou_2_unscaled: 0.5732 (0.5624)  cardinality_error_2_unscaled: 4.0000 (6.4890)  loss_rel_2_unscaled: 0.6224 (0.6626)  loss_ce_3_unscaled: 0.4481 (0.4586)  loss_bbox_3_unscaled: 0.2197 (0.2120)  loss_giou_3_unscaled: 0.5869 (0.5536)  cardinality_error_3_unscaled: 6.0000 (6.5230)  loss_rel_3_unscaled: 0.6366 (0.6685)  loss_ce_4_unscaled: 0.4587 (0.4585)  loss_bbox_4_unscaled: 0.2220 (0.2100)  loss_giou_4_unscaled: 0.5727 (0.5446)  cardinality_error_4_unscaled: 3.0000 (6.1098)  loss_rel_4_unscaled: 0.6050 (0.6784)  time: 0.2064  data: 0.0126  max mem: 1284
# Test:  [ 600/2919]  eta: 0:10:58  class_error: 35.29  sub_error: 20.00  obj_error: 20.00  rel_error: 80.00  loss: 18.6036 (20.2748)  loss_ce: 0.3792 (0.4616)  loss_bbox: 0.9170 (1.0564)  loss_giou: 1.0717 (1.0927)  loss_rel: 0.5697 (0.6915)  loss_ce_0: 0.4026 (0.5051)  loss_bbox_0: 1.0391 (1.1817)  loss_giou_0: 1.1331 (1.2426)  loss_rel_0: 0.5764 (0.6655)  loss_ce_1: 0.4163 (0.4837)  loss_bbox_1: 0.9812 (1.1170)  loss_giou_1: 1.0700 (1.1617)  loss_rel_1: 0.5635 (0.6611)  loss_ce_2: 0.4150 (0.4726)  loss_bbox_2: 0.9340 (1.0778)  loss_giou_2: 1.0504 (1.1292)  loss_rel_2: 0.6820 (0.6649)  loss_ce_3: 0.3964 (0.4654)  loss_bbox_3: 0.9716 (1.0644)  loss_giou_3: 1.0628 (1.1121)  loss_rel_3: 0.6767 (0.6714)  loss_ce_4: 0.3840 (0.4654)  loss_bbox_4: 0.9109 (1.0540)  loss_giou_4: 1.0789 (1.0956)  loss_rel_4: 0.5952 (0.6814)  loss_ce_unscaled: 0.3792 (0.4616)  class_error_unscaled: 33.3333 (35.2106)  sub_error_unscaled: 33.3333 (56.1128)  obj_error_unscaled: 50.0000 (53.7790)  loss_bbox_unscaled: 0.1834 (0.2113)  loss_giou_unscaled: 0.5358 (0.5464)  cardinality_error_unscaled: 7.0000 (6.3894)  loss_rel_unscaled: 0.5697 (0.6915)  rel_error_unscaled: 69.2308 (68.1958)  loss_ce_0_unscaled: 0.4026 (0.5051)  loss_bbox_0_unscaled: 0.2078 (0.2363)  loss_giou_0_unscaled: 0.5665 (0.6213)  cardinality_error_0_unscaled: 10.0000 (7.1364)  loss_rel_0_unscaled: 0.5764 (0.6655)  loss_ce_1_unscaled: 0.4163 (0.4837)  loss_bbox_1_unscaled: 0.1962 (0.2234)  loss_giou_1_unscaled: 0.5350 (0.5808)  cardinality_error_1_unscaled: 6.0000 (6.7754)  loss_rel_1_unscaled: 0.5635 (0.6611)  loss_ce_2_unscaled: 0.4150 (0.4726)  loss_bbox_2_unscaled: 0.1868 (0.2156)  loss_giou_2_unscaled: 0.5252 (0.5646)  cardinality_error_2_unscaled: 8.0000 (6.4759)  loss_rel_2_unscaled: 0.6820 (0.6649)  loss_ce_3_unscaled: 0.3964 (0.4654)  loss_bbox_3_unscaled: 0.1943 (0.2129)  loss_giou_3_unscaled: 0.5314 (0.5561)  cardinality_error_3_unscaled: 8.0000 (6.5125)  loss_rel_3_unscaled: 0.6767 (0.6714)  loss_ce_4_unscaled: 0.3840 (0.4654)  loss_bbox_4_unscaled: 0.1822 (0.2108)  loss_giou_4_unscaled: 0.5394 (0.5478)  cardinality_error_4_unscaled: 5.0000 (6.0948)  loss_rel_4_unscaled: 0.5952 (0.6814)  time: 0.2297  data: 0.0187  max mem: 1284
# Test:  [ 700/2919]  eta: 0:10:11  class_error: 38.10  sub_error: 83.33  obj_error: 66.67  rel_error: 83.33  loss: 21.2911 (20.4014)  loss_ce: 0.4129 (0.4646)  loss_bbox: 1.0267 (1.0636)  loss_giou: 1.2270 (1.0970)  loss_rel: 0.7019 (0.6956)  loss_ce_0: 0.4429 (0.5089)  loss_bbox_0: 1.1974 (1.1898)  loss_giou_0: 1.4120 (1.2493)  loss_rel_0: 0.7412 (0.6714)  loss_ce_1: 0.4723 (0.4884)  loss_bbox_1: 1.1029 (1.1233)  loss_giou_1: 1.2618 (1.1666)  loss_rel_1: 0.7161 (0.6679)  loss_ce_2: 0.4349 (0.4767)  loss_bbox_2: 1.1108 (1.0850)  loss_giou_2: 1.2901 (1.1346)  loss_rel_2: 0.7393 (0.6704)  loss_ce_3: 0.3892 (0.4682)  loss_bbox_3: 1.0599 (1.0723)  loss_giou_3: 1.2668 (1.1184)  loss_rel_3: 0.6460 (0.6753)  loss_ce_4: 0.4023 (0.4684)  loss_bbox_4: 1.0233 (1.0614)  loss_giou_4: 1.2634 (1.1009)  loss_rel_4: 0.6563 (0.6837)  loss_ce_unscaled: 0.4129 (0.4646)  class_error_unscaled: 30.0000 (35.3086)  sub_error_unscaled: 66.6667 (56.0250)  obj_error_unscaled: 53.8462 (53.1452)  loss_bbox_unscaled: 0.2053 (0.2127)  loss_giou_unscaled: 0.6135 (0.5485)  cardinality_error_unscaled: 4.0000 (6.3295)  loss_rel_unscaled: 0.7019 (0.6956)  rel_error_unscaled: 71.4286 (68.0626)  loss_ce_0_unscaled: 0.4429 (0.5089)  loss_bbox_0_unscaled: 0.2395 (0.2380)  loss_giou_0_unscaled: 0.7060 (0.6246)  cardinality_error_0_unscaled: 5.0000 (7.0499)  loss_rel_0_unscaled: 0.7412 (0.6714)  loss_ce_1_unscaled: 0.4723 (0.4884)  loss_bbox_1_unscaled: 0.2206 (0.2247)  loss_giou_1_unscaled: 0.6309 (0.5833)  cardinality_error_1_unscaled: 5.0000 (6.7090)  loss_rel_1_unscaled: 0.7161 (0.6679)  loss_ce_2_unscaled: 0.4349 (0.4767)  loss_bbox_2_unscaled: 0.2222 (0.2170)  loss_giou_2_unscaled: 0.6451 (0.5673)  cardinality_error_2_unscaled: 5.0000 (6.4037)  loss_rel_2_unscaled: 0.7393 (0.6704)  loss_ce_3_unscaled: 0.3892 (0.4682)  loss_bbox_3_unscaled: 0.2120 (0.2145)  loss_giou_3_unscaled: 0.6334 (0.5592)  cardinality_error_3_unscaled: 5.0000 (6.4679)  loss_rel_3_unscaled: 0.6460 (0.6753)  loss_ce_4_unscaled: 0.4023 (0.4684)  loss_bbox_4_unscaled: 0.2047 (0.2123)  loss_giou_4_unscaled: 0.6317 (0.5504)  cardinality_error_4_unscaled: 4.0000 (6.1084)  loss_rel_4_unscaled: 0.6563 (0.6837)  time: 0.2038  data: 0.0251  max mem: 1284
# Test:  [ 800/2919]  eta: 0:09:32  class_error: 100.00  sub_error: 100.00  obj_error: 100.00  rel_error: 100.00  loss: 19.4373 (20.3416)  loss_ce: 0.3643 (0.4648)  loss_bbox: 1.0355 (1.0547)  loss_giou: 1.0236 (1.0940)  loss_rel: 0.5776 (0.6985)  loss_ce_0: 0.3916 (0.5083)  loss_bbox_0: 1.1542 (1.1794)  loss_giou_0: 1.1375 (1.2438)  loss_rel_0: 0.5418 (0.6754)  loss_ce_1: 0.3724 (0.4883)  loss_bbox_1: 1.1163 (1.1123)  loss_giou_1: 1.0665 (1.1606)  loss_rel_1: 0.5059 (0.6713)  loss_ce_2: 0.3671 (0.4763)  loss_bbox_2: 1.1353 (1.0776)  loss_giou_2: 1.0414 (1.1304)  loss_rel_2: 0.5598 (0.6738)  loss_ce_3: 0.3470 (0.4687)  loss_bbox_3: 1.1231 (1.0637)  loss_giou_3: 1.0278 (1.1152)  loss_rel_3: 0.5517 (0.6780)  loss_ce_4: 0.3520 (0.4680)  loss_bbox_4: 1.0463 (1.0535)  loss_giou_4: 1.0326 (1.0983)  loss_rel_4: 0.5905 (0.6869)  loss_ce_unscaled: 0.3643 (0.4648)  class_error_unscaled: 30.7692 (35.3607)  sub_error_unscaled: 42.8571 (56.3565)  obj_error_unscaled: 50.0000 (53.3300)  loss_bbox_unscaled: 0.2071 (0.2109)  loss_giou_unscaled: 0.5118 (0.5470)  cardinality_error_unscaled: 4.0000 (6.3583)  loss_rel_unscaled: 0.5776 (0.6985)  rel_error_unscaled: 66.6667 (68.5214)  loss_ce_0_unscaled: 0.3916 (0.5083)  loss_bbox_0_unscaled: 0.2308 (0.2359)  loss_giou_0_unscaled: 0.5688 (0.6219)  cardinality_error_0_unscaled: 6.0000 (7.0237)  loss_rel_0_unscaled: 0.5418 (0.6754)  loss_ce_1_unscaled: 0.3724 (0.4883)  loss_bbox_1_unscaled: 0.2233 (0.2225)  loss_giou_1_unscaled: 0.5332 (0.5803)  cardinality_error_1_unscaled: 5.0000 (6.6654)  loss_rel_1_unscaled: 0.5059 (0.6713)  loss_ce_2_unscaled: 0.3671 (0.4763)  loss_bbox_2_unscaled: 0.2271 (0.2155)  loss_giou_2_unscaled: 0.5207 (0.5652)  cardinality_error_2_unscaled: 4.0000 (6.3945)  loss_rel_2_unscaled: 0.5598 (0.6738)  loss_ce_3_unscaled: 0.3470 (0.4687)  loss_bbox_3_unscaled: 0.2246 (0.2127)  loss_giou_3_unscaled: 0.5139 (0.5576)  cardinality_error_3_unscaled: 4.0000 (6.4182)  loss_rel_3_unscaled: 0.5517 (0.6780)  loss_ce_4_unscaled: 0.3520 (0.4680)  loss_bbox_4_unscaled: 0.2093 (0.2107)  loss_giou_4_unscaled: 0.5163 (0.5492)  cardinality_error_4_unscaled: 3.0000 (6.1111)  loss_rel_4_unscaled: 0.5905 (0.6869)  time: 0.1990  data: 0.0236  max mem: 1284
# Test:  [ 900/2919]  eta: 0:09:00  class_error: 25.00  sub_error: 88.89  obj_error: 33.33  rel_error: 44.44  loss: 18.5818 (20.3989)  loss_ce: 0.5089 (0.4677)  loss_bbox: 0.8681 (1.0587)  loss_giou: 1.0031 (1.0950)  loss_rel: 0.6897 (0.7024)  loss_ce_0: 0.5368 (0.5103)  loss_bbox_0: 1.0349 (1.1821)  loss_giou_0: 1.2452 (1.2423)  loss_rel_0: 0.6324 (0.6780)  loss_ce_1: 0.4961 (0.4910)  loss_bbox_1: 0.8757 (1.1153)  loss_giou_1: 1.0954 (1.1605)  loss_rel_1: 0.6182 (0.6752)  loss_ce_2: 0.4889 (0.4789)  loss_bbox_2: 0.9039 (1.0818)  loss_giou_2: 1.0698 (1.1296)  loss_rel_2: 0.5700 (0.6769)  loss_ce_3: 0.5079 (0.4717)  loss_bbox_3: 0.8779 (1.0672)  loss_giou_3: 0.9591 (1.1146)  loss_rel_3: 0.6235 (0.6827)  loss_ce_4: 0.5127 (0.4711)  loss_bbox_4: 0.8712 (1.0574)  loss_giou_4: 0.9526 (1.0984)  loss_rel_4: 0.6362 (0.6903)  loss_ce_unscaled: 0.5089 (0.4677)  class_error_unscaled: 36.3636 (35.4428)  sub_error_unscaled: 60.0000 (55.9427)  obj_error_unscaled: 58.3333 (52.6583)  loss_bbox_unscaled: 0.1736 (0.2117)  loss_giou_unscaled: 0.5015 (0.5475)  cardinality_error_unscaled: 8.0000 (6.4595)  loss_rel_unscaled: 0.6897 (0.7024)  rel_error_unscaled: 69.2308 (68.1016)  loss_ce_0_unscaled: 0.5368 (0.5103)  loss_bbox_0_unscaled: 0.2070 (0.2364)  loss_giou_0_unscaled: 0.6226 (0.6212)  cardinality_error_0_unscaled: 6.0000 (7.0943)  loss_rel_0_unscaled: 0.6324 (0.6780)  loss_ce_1_unscaled: 0.4961 (0.4910)  loss_bbox_1_unscaled: 0.1751 (0.2231)  loss_giou_1_unscaled: 0.5477 (0.5803)  cardinality_error_1_unscaled: 6.0000 (6.7170)  loss_rel_1_unscaled: 0.6182 (0.6752)  loss_ce_2_unscaled: 0.4889 (0.4789)  loss_bbox_2_unscaled: 0.1808 (0.2164)  loss_giou_2_unscaled: 0.5349 (0.5648)  cardinality_error_2_unscaled: 4.0000 (6.4495)  loss_rel_2_unscaled: 0.5700 (0.6769)  loss_ce_3_unscaled: 0.5079 (0.4717)  loss_bbox_3_unscaled: 0.1756 (0.2134)  loss_giou_3_unscaled: 0.4795 (0.5573)  cardinality_error_3_unscaled: 6.0000 (6.4617)  loss_rel_3_unscaled: 0.6235 (0.6827)  loss_ce_4_unscaled: 0.5127 (0.4711)  loss_bbox_4_unscaled: 0.1742 (0.2115)  loss_giou_4_unscaled: 0.4763 (0.5492)  cardinality_error_4_unscaled: 6.0000 (6.1931)  loss_rel_4_unscaled: 0.6362 (0.6903)  time: 0.2254  data: 0.0466  max mem: 1284
# Test:  [1000/2919]  eta: 0:08:30  class_error: 11.11  sub_error: 0.00  obj_error: 0.00  rel_error: 75.00  loss: 18.4958 (20.3714)  loss_ce: 0.4644 (0.4703)  loss_bbox: 0.8074 (1.0589)  loss_giou: 0.9618 (1.0888)  loss_rel: 0.7754 (0.7002)  loss_ce_0: 0.4728 (0.5115)  loss_bbox_0: 0.9830 (1.1806)  loss_giou_0: 1.1065 (1.2350)  loss_rel_0: 0.7782 (0.6783)  loss_ce_1: 0.4523 (0.4926)  loss_bbox_1: 0.9785 (1.1160)  loss_giou_1: 1.0559 (1.1544)  loss_rel_1: 0.7187 (0.6751)  loss_ce_2: 0.4993 (0.4803)  loss_bbox_2: 0.8199 (1.0842)  loss_giou_2: 0.9950 (1.1239)  loss_rel_2: 0.8160 (0.6761)  loss_ce_3: 0.4540 (0.4739)  loss_bbox_3: 0.8540 (1.0685)  loss_giou_3: 0.9400 (1.1081)  loss_rel_3: 0.8071 (0.6825)  loss_ce_4: 0.4627 (0.4732)  loss_bbox_4: 0.7913 (1.0586)  loss_giou_4: 0.9605 (1.0921)  loss_rel_4: 0.7724 (0.6881)  loss_ce_unscaled: 0.4644 (0.4703)  class_error_unscaled: 38.4615 (35.6970)  sub_error_unscaled: 57.1429 (56.3568)  obj_error_unscaled: 53.8462 (52.7985)  loss_bbox_unscaled: 0.1615 (0.2118)  loss_giou_unscaled: 0.4809 (0.5444)  cardinality_error_unscaled: 3.0000 (6.5045)  loss_rel_unscaled: 0.7754 (0.7002)  rel_error_unscaled: 71.4286 (68.0804)  loss_ce_0_unscaled: 0.4728 (0.5115)  loss_bbox_0_unscaled: 0.1966 (0.2361)  loss_giou_0_unscaled: 0.5533 (0.6175)  cardinality_error_0_unscaled: 4.0000 (7.1049)  loss_rel_0_unscaled: 0.7782 (0.6783)  loss_ce_1_unscaled: 0.4523 (0.4926)  loss_bbox_1_unscaled: 0.1957 (0.2232)  loss_giou_1_unscaled: 0.5280 (0.5772)  cardinality_error_1_unscaled: 4.0000 (6.7762)  loss_rel_1_unscaled: 0.7187 (0.6751)  loss_ce_2_unscaled: 0.4993 (0.4803)  loss_bbox_2_unscaled: 0.1640 (0.2168)  loss_giou_2_unscaled: 0.4975 (0.5619)  cardinality_error_2_unscaled: 6.0000 (6.5105)  loss_rel_2_unscaled: 0.8160 (0.6761)  loss_ce_3_unscaled: 0.4540 (0.4739)  loss_bbox_3_unscaled: 0.1708 (0.2137)  loss_giou_3_unscaled: 0.4700 (0.5540)  cardinality_error_3_unscaled: 5.0000 (6.5015)  loss_rel_3_unscaled: 0.8071 (0.6825)  loss_ce_4_unscaled: 0.4627 (0.4732)  loss_bbox_4_unscaled: 0.1583 (0.2117)  loss_giou_4_unscaled: 0.4803 (0.5461)  cardinality_error_4_unscaled: 3.0000 (6.2318)  loss_rel_4_unscaled: 0.7724 (0.6881)  time: 0.2128  data: 0.0360  max mem: 1284
# Test:  [1100/2919]  eta: 0:07:57  class_error: 26.67  sub_error: 66.67  obj_error: 66.67  rel_error: 50.00  loss: 17.5211 (20.3007)  loss_ce: 0.3515 (0.4699)  loss_bbox: 0.8962 (1.0534)  loss_giou: 0.9671 (1.0858)  loss_rel: 0.5843 (0.6963)  loss_ce_0: 0.4111 (0.5108)  loss_bbox_0: 1.0990 (1.1786)  loss_giou_0: 1.0409 (1.2329)  loss_rel_0: 0.6351 (0.6734)  loss_ce_1: 0.3915 (0.4919)  loss_bbox_1: 1.0439 (1.1122)  loss_giou_1: 1.0213 (1.1519)  loss_rel_1: 0.5868 (0.6712)  loss_ce_2: 0.3888 (0.4801)  loss_bbox_2: 0.8949 (1.0793)  loss_giou_2: 0.9538 (1.1202)  loss_rel_2: 0.5841 (0.6736)  loss_ce_3: 0.3703 (0.4741)  loss_bbox_3: 0.9177 (1.0628)  loss_giou_3: 0.9319 (1.1036)  loss_rel_3: 0.5828 (0.6799)  loss_ce_4: 0.3722 (0.4733)  loss_bbox_4: 0.9394 (1.0529)  loss_giou_4: 0.9620 (1.0882)  loss_rel_4: 0.5391 (0.6843)  loss_ce_unscaled: 0.3515 (0.4699)  class_error_unscaled: 33.3333 (35.9438)  sub_error_unscaled: 57.1429 (56.2679)  obj_error_unscaled: 25.0000 (52.6172)  loss_bbox_unscaled: 0.1792 (0.2107)  loss_giou_unscaled: 0.4836 (0.5429)  cardinality_error_unscaled: 5.0000 (6.5186)  loss_rel_unscaled: 0.5843 (0.6963)  rel_error_unscaled: 57.1429 (67.8766)  loss_ce_0_unscaled: 0.4111 (0.5108)  loss_bbox_0_unscaled: 0.2198 (0.2357)  loss_giou_0_unscaled: 0.5205 (0.6165)  cardinality_error_0_unscaled: 6.0000 (7.1063)  loss_rel_0_unscaled: 0.6351 (0.6734)  loss_ce_1_unscaled: 0.3915 (0.4919)  loss_bbox_1_unscaled: 0.2088 (0.2224)  loss_giou_1_unscaled: 0.5106 (0.5760)  cardinality_error_1_unscaled: 7.0000 (6.7566)  loss_rel_1_unscaled: 0.5868 (0.6712)  loss_ce_2_unscaled: 0.3888 (0.4801)  loss_bbox_2_unscaled: 0.1790 (0.2159)  loss_giou_2_unscaled: 0.4769 (0.5601)  cardinality_error_2_unscaled: 6.0000 (6.5241)  loss_rel_2_unscaled: 0.5841 (0.6736)  loss_ce_3_unscaled: 0.3703 (0.4741)  loss_bbox_3_unscaled: 0.1835 (0.2126)  loss_giou_3_unscaled: 0.4659 (0.5518)  cardinality_error_3_unscaled: 7.0000 (6.5332)  loss_rel_3_unscaled: 0.5828 (0.6799)  loss_ce_4_unscaled: 0.3722 (0.4733)  loss_bbox_4_unscaled: 0.1879 (0.2106)  loss_giou_4_unscaled: 0.4810 (0.5441)  cardinality_error_4_unscaled: 5.0000 (6.2670)  loss_rel_4_unscaled: 0.5391 (0.6843)  time: 0.2445  data: 0.0476  max mem: 1284
# Test:  [1200/2919]  eta: 0:07:24  class_error: 47.37  sub_error: 40.00  obj_error: 30.00  rel_error: 80.00  loss: 18.3764 (20.2869)  loss_ce: 0.3020 (0.4663)  loss_bbox: 1.0060 (1.0564)  loss_giou: 1.0735 (1.0865)  loss_rel: 0.5606 (0.6951)  loss_ce_0: 0.4065 (0.5075)  loss_bbox_0: 1.0318 (1.1785)  loss_giou_0: 1.2249 (1.2316)  loss_rel_0: 0.4862 (0.6725)  loss_ce_1: 0.3340 (0.4884)  loss_bbox_1: 1.0130 (1.1139)  loss_giou_1: 1.1341 (1.1519)  loss_rel_1: 0.4223 (0.6706)  loss_ce_2: 0.3346 (0.4769)  loss_bbox_2: 0.9955 (1.0814)  loss_giou_2: 1.0742 (1.1205)  loss_rel_2: 0.4391 (0.6723)  loss_ce_3: 0.3156 (0.4712)  loss_bbox_3: 0.9937 (1.0649)  loss_giou_3: 1.0984 (1.1033)  loss_rel_3: 0.4909 (0.6791)  loss_ce_4: 0.3062 (0.4700)  loss_bbox_4: 0.9931 (1.0561)  loss_giou_4: 1.0729 (1.0889)  loss_rel_4: 0.5273 (0.6833)  loss_ce_unscaled: 0.3020 (0.4663)  class_error_unscaled: 38.8889 (35.7160)  sub_error_unscaled: 33.3333 (55.6039)  obj_error_unscaled: 30.0000 (52.0269)  loss_bbox_unscaled: 0.2012 (0.2113)  loss_giou_unscaled: 0.5367 (0.5433)  cardinality_error_unscaled: 6.0000 (6.5420)  loss_rel_unscaled: 0.5606 (0.6951)  rel_error_unscaled: 60.0000 (67.7584)  loss_ce_0_unscaled: 0.4065 (0.5075)  loss_bbox_0_unscaled: 0.2064 (0.2357)  loss_giou_0_unscaled: 0.6125 (0.6158)  cardinality_error_0_unscaled: 6.0000 (7.1099)  loss_rel_0_unscaled: 0.4862 (0.6725)  loss_ce_1_unscaled: 0.3340 (0.4884)  loss_bbox_1_unscaled: 0.2026 (0.2228)  loss_giou_1_unscaled: 0.5671 (0.5759)  cardinality_error_1_unscaled: 7.0000 (6.7535)  loss_rel_1_unscaled: 0.4223 (0.6706)  loss_ce_2_unscaled: 0.3346 (0.4769)  loss_bbox_2_unscaled: 0.1991 (0.2163)  loss_giou_2_unscaled: 0.5371 (0.5603)  cardinality_error_2_unscaled: 7.0000 (6.5279)  loss_rel_2_unscaled: 0.4391 (0.6723)  loss_ce_3_unscaled: 0.3156 (0.4712)  loss_bbox_3_unscaled: 0.1987 (0.2130)  loss_giou_3_unscaled: 0.5492 (0.5516)  cardinality_error_3_unscaled: 6.0000 (6.5279)  loss_rel_3_unscaled: 0.4909 (0.6791)  loss_ce_4_unscaled: 0.3062 (0.4700)  loss_bbox_4_unscaled: 0.1986 (0.2112)  loss_giou_4_unscaled: 0.5364 (0.5445)  cardinality_error_4_unscaled: 5.0000 (6.2656)  loss_rel_4_unscaled: 0.5273 (0.6833)  time: 0.2286  data: 0.0505  max mem: 1284
# Test:  [1300/2919]  eta: 0:06:55  class_error: 19.05  sub_error: 47.62  obj_error: 61.90  rel_error: 71.43  loss: 19.1192 (20.0687)  loss_ce: 0.2799 (0.4594)  loss_bbox: 0.8102 (1.0428)  loss_giou: 0.9789 (1.0768)  loss_rel: 0.5932 (0.6880)  loss_ce_0: 0.3414 (0.5011)  loss_bbox_0: 1.0627 (1.1664)  loss_giou_0: 1.0773 (1.2218)  loss_rel_0: 0.5332 (0.6652)  loss_ce_1: 0.3219 (0.4817)  loss_bbox_1: 0.9359 (1.1003)  loss_giou_1: 1.0421 (1.1423)  loss_rel_1: 0.5851 (0.6634)  loss_ce_2: 0.3096 (0.4701)  loss_bbox_2: 0.9602 (1.0683)  loss_giou_2: 1.0329 (1.1113)  loss_rel_2: 0.6303 (0.6652)  loss_ce_3: 0.3098 (0.4642)  loss_bbox_3: 0.9170 (1.0516)  loss_giou_3: 0.9882 (1.0946)  loss_rel_3: 0.6959 (0.6720)  loss_ce_4: 0.2985 (0.4630)  loss_bbox_4: 0.8129 (1.0426)  loss_giou_4: 0.9201 (1.0798)  loss_rel_4: 0.5990 (0.6766)  loss_ce_unscaled: 0.2799 (0.4594)  class_error_unscaled: 27.2727 (35.2468)  sub_error_unscaled: 47.6190 (55.0176)  obj_error_unscaled: 60.0000 (51.7540)  loss_bbox_unscaled: 0.1620 (0.2086)  loss_giou_unscaled: 0.4894 (0.5384)  cardinality_error_unscaled: 4.0000 (6.5611)  loss_rel_unscaled: 0.5932 (0.6880)  rel_error_unscaled: 77.7778 (67.5095)  loss_ce_0_unscaled: 0.3414 (0.5011)  loss_bbox_0_unscaled: 0.2125 (0.2333)  loss_giou_0_unscaled: 0.5387 (0.6109)  cardinality_error_0_unscaled: 7.0000 (7.1337)  loss_rel_0_unscaled: 0.5332 (0.6652)  loss_ce_1_unscaled: 0.3219 (0.4817)  loss_bbox_1_unscaled: 0.1872 (0.2201)  loss_giou_1_unscaled: 0.5210 (0.5712)  cardinality_error_1_unscaled: 5.0000 (6.7594)  loss_rel_1_unscaled: 0.5851 (0.6634)  loss_ce_2_unscaled: 0.3096 (0.4701)  loss_bbox_2_unscaled: 0.1920 (0.2137)  loss_giou_2_unscaled: 0.5165 (0.5557)  cardinality_error_2_unscaled: 5.0000 (6.5457)  loss_rel_2_unscaled: 0.6303 (0.6652)  loss_ce_3_unscaled: 0.3098 (0.4642)  loss_bbox_3_unscaled: 0.1834 (0.2103)  loss_giou_3_unscaled: 0.4941 (0.5473)  cardinality_error_3_unscaled: 4.0000 (6.5342)  loss_rel_3_unscaled: 0.6959 (0.6720)  loss_ce_4_unscaled: 0.2985 (0.4630)  loss_bbox_4_unscaled: 0.1626 (0.2085)  loss_giou_4_unscaled: 0.4601 (0.5399)  cardinality_error_4_unscaled: 4.0000 (6.2952)  loss_rel_4_unscaled: 0.5990 (0.6766)  time: 0.2188  data: 0.0449  max mem: 1284
# Test:  [1400/2919]  eta: 0:06:27  class_error: 37.50  sub_error: 100.00  obj_error: 33.33  rel_error: 33.33  loss: 17.2308 (19.8732)  loss_ce: 0.2968 (0.4546)  loss_bbox: 0.7554 (1.0287)  loss_giou: 1.0257 (1.0720)  loss_rel: 0.3636 (0.6760)  loss_ce_0: 0.3333 (0.4972)  loss_bbox_0: 0.9603 (1.1553)  loss_giou_0: 1.2162 (1.2198)  loss_rel_0: 0.4331 (0.6544)  loss_ce_1: 0.3165 (0.4771)  loss_bbox_1: 0.8298 (1.0878)  loss_giou_1: 1.1208 (1.1390)  loss_rel_1: 0.3900 (0.6532)  loss_ce_2: 0.3059 (0.4655)  loss_bbox_2: 0.8409 (1.0552)  loss_giou_2: 1.0513 (1.1077)  loss_rel_2: 0.4224 (0.6548)  loss_ce_3: 0.2724 (0.4595)  loss_bbox_3: 0.8507 (1.0371)  loss_giou_3: 1.0434 (1.0900)  loss_rel_3: 0.3935 (0.6611)  loss_ce_4: 0.2812 (0.4581)  loss_bbox_4: 0.8013 (1.0287)  loss_giou_4: 1.0253 (1.0750)  loss_rel_4: 0.3650 (0.6653)  loss_ce_unscaled: 0.2968 (0.4546)  class_error_unscaled: 30.7692 (34.9142)  sub_error_unscaled: 60.0000 (54.8800)  obj_error_unscaled: 33.3333 (51.4530)  loss_bbox_unscaled: 0.1511 (0.2057)  loss_giou_unscaled: 0.5129 (0.5360)  cardinality_error_unscaled: 5.0000 (6.6296)  loss_rel_unscaled: 0.3636 (0.6760)  rel_error_unscaled: 66.6667 (67.2904)  loss_ce_0_unscaled: 0.3333 (0.4972)  loss_bbox_0_unscaled: 0.1921 (0.2311)  loss_giou_0_unscaled: 0.6081 (0.6099)  cardinality_error_0_unscaled: 7.0000 (7.2198)  loss_rel_0_unscaled: 0.4331 (0.6544)  loss_ce_1_unscaled: 0.3165 (0.4771)  loss_bbox_1_unscaled: 0.1660 (0.2176)  loss_giou_1_unscaled: 0.5604 (0.5695)  cardinality_error_1_unscaled: 7.0000 (6.8423)  loss_rel_1_unscaled: 0.3900 (0.6532)  loss_ce_2_unscaled: 0.3059 (0.4655)  loss_bbox_2_unscaled: 0.1682 (0.2110)  loss_giou_2_unscaled: 0.5256 (0.5538)  cardinality_error_2_unscaled: 4.0000 (6.6260)  loss_rel_2_unscaled: 0.4224 (0.6548)  loss_ce_3_unscaled: 0.2724 (0.4595)  loss_bbox_3_unscaled: 0.1701 (0.2074)  loss_giou_3_unscaled: 0.5217 (0.5450)  cardinality_error_3_unscaled: 5.0000 (6.5896)  loss_rel_3_unscaled: 0.3935 (0.6611)  loss_ce_4_unscaled: 0.2812 (0.4581)  loss_bbox_4_unscaled: 0.1603 (0.2057)  loss_giou_4_unscaled: 0.5126 (0.5375)  cardinality_error_4_unscaled: 6.0000 (6.3897)  loss_rel_4_unscaled: 0.3650 (0.6653)  time: 0.2143  data: 0.0344  max mem: 1284
# Test:  [1500/2919]  eta: 0:06:00  class_error: 28.57  sub_error: 33.33  obj_error: 0.00  rel_error: 0.00  loss: 13.6055 (19.7370)  loss_ce: 0.2796 (0.4491)  loss_bbox: 0.5476 (1.0207)  loss_giou: 0.8535 (1.0693)  loss_rel: 0.4909 (0.6686)  loss_ce_0: 0.3423 (0.4913)  loss_bbox_0: 0.6457 (1.1494)  loss_giou_0: 0.9895 (1.2192)  loss_rel_0: 0.5173 (0.6469)  loss_ce_1: 0.2924 (0.4716)  loss_bbox_1: 0.6520 (1.0804)  loss_giou_1: 0.8617 (1.1371)  loss_rel_1: 0.5437 (0.6461)  loss_ce_2: 0.2903 (0.4600)  loss_bbox_2: 0.6236 (1.0476)  loss_giou_2: 0.8206 (1.1052)  loss_rel_2: 0.5148 (0.6474)  loss_ce_3: 0.2902 (0.4537)  loss_bbox_3: 0.5645 (1.0296)  loss_giou_3: 0.8363 (1.0871)  loss_rel_3: 0.5297 (0.6533)  loss_ce_4: 0.2881 (0.4524)  loss_bbox_4: 0.5406 (1.0213)  loss_giou_4: 0.8036 (1.0720)  loss_rel_4: 0.5117 (0.6578)  loss_ce_unscaled: 0.2796 (0.4491)  class_error_unscaled: 28.5714 (34.5028)  sub_error_unscaled: 33.3333 (54.6227)  obj_error_unscaled: 33.3333 (51.1563)  loss_bbox_unscaled: 0.1095 (0.2041)  loss_giou_unscaled: 0.4267 (0.5346)  cardinality_error_unscaled: 8.0000 (6.6676)  loss_rel_unscaled: 0.4909 (0.6686)  rel_error_unscaled: 60.0000 (67.2562)  loss_ce_0_unscaled: 0.3423 (0.4913)  loss_bbox_0_unscaled: 0.1291 (0.2299)  loss_giou_0_unscaled: 0.4948 (0.6096)  cardinality_error_0_unscaled: 10.0000 (7.2418)  loss_rel_0_unscaled: 0.5173 (0.6469)  loss_ce_1_unscaled: 0.2924 (0.4716)  loss_bbox_1_unscaled: 0.1304 (0.2161)  loss_giou_1_unscaled: 0.4308 (0.5685)  cardinality_error_1_unscaled: 7.0000 (6.8474)  loss_rel_1_unscaled: 0.5437 (0.6461)  loss_ce_2_unscaled: 0.2903 (0.4600)  loss_bbox_2_unscaled: 0.1247 (0.2095)  loss_giou_2_unscaled: 0.4103 (0.5526)  cardinality_error_2_unscaled: 7.0000 (6.6536)  loss_rel_2_unscaled: 0.5148 (0.6474)  loss_ce_3_unscaled: 0.2902 (0.4537)  loss_bbox_3_unscaled: 0.1129 (0.2059)  loss_giou_3_unscaled: 0.4181 (0.5435)  cardinality_error_3_unscaled: 6.0000 (6.5849)  loss_rel_3_unscaled: 0.5297 (0.6533)  loss_ce_4_unscaled: 0.2881 (0.4524)  loss_bbox_4_unscaled: 0.1081 (0.2043)  loss_giou_4_unscaled: 0.4018 (0.5360)  cardinality_error_4_unscaled: 8.0000 (6.4264)  loss_rel_4_unscaled: 0.5117 (0.6578)  time: 0.2439  data: 0.0350  max mem: 1284
# Test:  [1600/2919]  eta: 0:05:48  class_error: 14.29  sub_error: 100.00  obj_error: 100.00  rel_error: 100.00  loss: 14.0874 (19.6405)  loss_ce: 0.3066 (0.4439)  loss_bbox: 0.6475 (1.0161)  loss_giou: 0.8351 (1.0686)  loss_rel: 0.5458 (0.6647)  loss_ce_0: 0.3590 (0.4859)  loss_bbox_0: 0.7596 (1.1437)  loss_giou_0: 1.0893 (1.2178)  loss_rel_0: 0.4533 (0.6431)  loss_ce_1: 0.3341 (0.4666)  loss_bbox_1: 0.6547 (1.0729)  loss_giou_1: 0.9201 (1.1353)  loss_rel_1: 0.4156 (0.6428)  loss_ce_2: 0.3311 (0.4549)  loss_bbox_2: 0.7003 (1.0406)  loss_giou_2: 0.9496 (1.1038)  loss_rel_2: 0.5137 (0.6440)  loss_ce_3: 0.3310 (0.4486)  loss_bbox_3: 0.6353 (1.0238)  loss_giou_3: 0.8880 (1.0858)  loss_rel_3: 0.4924 (0.6493)  loss_ce_4: 0.3221 (0.4473)  loss_bbox_4: 0.6096 (1.0161)  loss_giou_4: 0.8525 (1.0710)  loss_rel_4: 0.4940 (0.6538)  loss_ce_unscaled: 0.3066 (0.4439)  class_error_unscaled: 23.0769 (33.9976)  sub_error_unscaled: 31.2500 (54.1457)  obj_error_unscaled: 50.0000 (50.9827)  loss_bbox_unscaled: 0.1295 (0.2032)  loss_giou_unscaled: 0.4175 (0.5343)  cardinality_error_unscaled: 5.0000 (6.7283)  loss_rel_unscaled: 0.5458 (0.6647)  rel_error_unscaled: 66.6667 (67.3891)  loss_ce_0_unscaled: 0.3590 (0.4859)  loss_bbox_0_unscaled: 0.1519 (0.2287)  loss_giou_0_unscaled: 0.5446 (0.6089)  cardinality_error_0_unscaled: 6.0000 (7.3229)  loss_rel_0_unscaled: 0.4533 (0.6431)  loss_ce_1_unscaled: 0.3341 (0.4666)  loss_bbox_1_unscaled: 0.1309 (0.2146)  loss_giou_1_unscaled: 0.4601 (0.5676)  cardinality_error_1_unscaled: 5.0000 (6.9001)  loss_rel_1_unscaled: 0.4156 (0.6428)  loss_ce_2_unscaled: 0.3311 (0.4549)  loss_bbox_2_unscaled: 0.1401 (0.2081)  loss_giou_2_unscaled: 0.4748 (0.5519)  cardinality_error_2_unscaled: 4.0000 (6.7083)  loss_rel_2_unscaled: 0.5137 (0.6440)  loss_ce_3_unscaled: 0.3310 (0.4486)  loss_bbox_3_unscaled: 0.1271 (0.2048)  loss_giou_3_unscaled: 0.4440 (0.5429)  cardinality_error_3_unscaled: 6.0000 (6.6302)  loss_rel_3_unscaled: 0.4924 (0.6493)  loss_ce_4_unscaled: 0.3221 (0.4473)  loss_bbox_4_unscaled: 0.1219 (0.2032)  loss_giou_4_unscaled: 0.4262 (0.5355)  cardinality_error_4_unscaled: 5.0000 (6.4747)  loss_rel_4_unscaled: 0.4940 (0.6538)  time: 0.2067  data: 0.0344  max mem: 1284
# Test:  [1700/2919]  eta: 0:05:21  class_error: 33.33  sub_error: 0.00  obj_error: 50.00  rel_error: 50.00  loss: 12.0690 (19.4056)  loss_ce: 0.2576 (0.4367)  loss_bbox: 0.5013 (1.0031)  loss_giou: 0.6992 (1.0578)  loss_rel: 0.4356 (0.6560)  loss_ce_0: 0.2946 (0.4784)  loss_bbox_0: 0.6518 (1.1306)  loss_giou_0: 0.9285 (1.2067)  loss_rel_0: 0.4764 (0.6356)  loss_ce_1: 0.2930 (0.4592)  loss_bbox_1: 0.6493 (1.0603)  loss_giou_1: 0.8176 (1.1246)  loss_rel_1: 0.4808 (0.6349)  loss_ce_2: 0.2789 (0.4476)  loss_bbox_2: 0.5193 (1.0278)  loss_giou_2: 0.7352 (1.0931)  loss_rel_2: 0.5460 (0.6358)  loss_ce_3: 0.2735 (0.4416)  loss_bbox_3: 0.5340 (1.0108)  loss_giou_3: 0.7083 (1.0749)  loss_rel_3: 0.4626 (0.6409)  loss_ce_4: 0.2651 (0.4399)  loss_bbox_4: 0.5034 (1.0035)  loss_giou_4: 0.6862 (1.0605)  loss_rel_4: 0.4690 (0.6454)  loss_ce_unscaled: 0.2576 (0.4367)  class_error_unscaled: 16.6667 (33.3858)  sub_error_unscaled: 33.3333 (53.5257)  obj_error_unscaled: 25.0000 (50.5617)  loss_bbox_unscaled: 0.1003 (0.2006)  loss_giou_unscaled: 0.3496 (0.5289)  cardinality_error_unscaled: 9.0000 (6.8289)  loss_rel_unscaled: 0.4356 (0.6560)  rel_error_unscaled: 57.1429 (67.0524)  loss_ce_0_unscaled: 0.2946 (0.4784)  loss_bbox_0_unscaled: 0.1304 (0.2261)  loss_giou_0_unscaled: 0.4642 (0.6033)  cardinality_error_0_unscaled: 11.0000 (7.4844)  loss_rel_0_unscaled: 0.4764 (0.6356)  loss_ce_1_unscaled: 0.2930 (0.4592)  loss_bbox_1_unscaled: 0.1299 (0.2121)  loss_giou_1_unscaled: 0.4088 (0.5623)  cardinality_error_1_unscaled: 10.0000 (7.0288)  loss_rel_1_unscaled: 0.4808 (0.6349)  loss_ce_2_unscaled: 0.2789 (0.4476)  loss_bbox_2_unscaled: 0.1039 (0.2056)  loss_giou_2_unscaled: 0.3676 (0.5466)  cardinality_error_2_unscaled: 11.0000 (6.8307)  loss_rel_2_unscaled: 0.5460 (0.6358)  loss_ce_3_unscaled: 0.2735 (0.4416)  loss_bbox_3_unscaled: 0.1068 (0.2022)  loss_giou_3_unscaled: 0.3541 (0.5375)  cardinality_error_3_unscaled: 11.0000 (6.7537)  loss_rel_3_unscaled: 0.4626 (0.6409)  loss_ce_4_unscaled: 0.2651 (0.4399)  loss_bbox_4_unscaled: 0.1007 (0.2007)  loss_giou_4_unscaled: 0.3431 (0.5303)  cardinality_error_4_unscaled: 10.0000 (6.5820)  loss_rel_4_unscaled: 0.4690 (0.6454)  time: 0.1903  data: 0.0206  max mem: 1284
# Test:  [1800/2919]  eta: 0:04:52  class_error: 38.46  sub_error: 33.33  obj_error: 33.33  rel_error: 41.67  loss: 17.6627 (19.3868)  loss_ce: 0.3936 (0.4367)  loss_bbox: 0.7592 (1.0029)  loss_giou: 0.9960 (1.0558)  loss_rel: 0.5565 (0.6553)  loss_ce_0: 0.4240 (0.4782)  loss_bbox_0: 0.8983 (1.1301)  loss_giou_0: 1.1481 (1.2033)  loss_rel_0: 0.6310 (0.6363)  loss_ce_1: 0.4055 (0.4589)  loss_bbox_1: 0.7988 (1.0594)  loss_giou_1: 1.0038 (1.1214)  loss_rel_1: 0.6025 (0.6346)  loss_ce_2: 0.3896 (0.4475)  loss_bbox_2: 0.8133 (1.0287)  loss_giou_2: 1.0339 (1.0910)  loss_rel_2: 0.5326 (0.6350)  loss_ce_3: 0.3961 (0.4414)  loss_bbox_3: 0.7343 (1.0106)  loss_giou_3: 1.0525 (1.0730)  loss_rel_3: 0.5746 (0.6402)  loss_ce_4: 0.4021 (0.4398)  loss_bbox_4: 0.7703 (1.0035)  loss_giou_4: 1.0183 (1.0585)  loss_rel_4: 0.5537 (0.6444)  loss_ce_unscaled: 0.3936 (0.4367)  class_error_unscaled: 25.0000 (33.3333)  sub_error_unscaled: 50.0000 (53.2987)  obj_error_unscaled: 50.0000 (50.4153)  loss_bbox_unscaled: 0.1518 (0.2006)  loss_giou_unscaled: 0.4980 (0.5279)  cardinality_error_unscaled: 7.0000 (6.8973)  loss_rel_unscaled: 0.5565 (0.6553)  rel_error_unscaled: 66.6667 (66.9084)  loss_ce_0_unscaled: 0.4240 (0.4782)  loss_bbox_0_unscaled: 0.1797 (0.2260)  loss_giou_0_unscaled: 0.5740 (0.6017)  cardinality_error_0_unscaled: 8.0000 (7.5597)  loss_rel_0_unscaled: 0.6310 (0.6363)  loss_ce_1_unscaled: 0.4055 (0.4589)  loss_bbox_1_unscaled: 0.1598 (0.2119)  loss_giou_1_unscaled: 0.5019 (0.5607)  cardinality_error_1_unscaled: 7.0000 (7.0983)  loss_rel_1_unscaled: 0.6025 (0.6346)  loss_ce_2_unscaled: 0.3896 (0.4475)  loss_bbox_2_unscaled: 0.1627 (0.2057)  loss_giou_2_unscaled: 0.5169 (0.5455)  cardinality_error_2_unscaled: 8.0000 (6.8939)  loss_rel_2_unscaled: 0.5326 (0.6350)  loss_ce_3_unscaled: 0.3961 (0.4414)  loss_bbox_3_unscaled: 0.1469 (0.2021)  loss_giou_3_unscaled: 0.5262 (0.5365)  cardinality_error_3_unscaled: 8.0000 (6.8123)  loss_rel_3_unscaled: 0.5746 (0.6402)  loss_ce_4_unscaled: 0.4021 (0.4398)  loss_bbox_4_unscaled: 0.1541 (0.2007)  loss_giou_4_unscaled: 0.5091 (0.5293)  cardinality_error_4_unscaled: 7.0000 (6.6474)  loss_rel_4_unscaled: 0.5537 (0.6444)  time: 0.2233  data: 0.0086  max mem: 1284
# Test:  [1900/2919]  eta: 0:04:26  class_error: 9.09  sub_error: 75.00  obj_error: 25.00  rel_error: 75.00  loss: 19.2213 (19.5124)  loss_ce: 0.4340 (0.4400)  loss_bbox: 0.9473 (1.0120)  loss_giou: 0.9439 (1.0595)  loss_rel: 0.5983 (0.6604)  loss_ce_0: 0.4742 (0.4815)  loss_bbox_0: 1.0647 (1.1389)  loss_giou_0: 1.0990 (1.2072)  loss_rel_0: 0.5613 (0.6407)  loss_ce_1: 0.4517 (0.4623)  loss_bbox_1: 0.8614 (1.0688)  loss_giou_1: 1.0193 (1.1255)  loss_rel_1: 0.5601 (0.6393)  loss_ce_2: 0.4470 (0.4509)  loss_bbox_2: 0.9314 (1.0377)  loss_giou_2: 1.0919 (1.0950)  loss_rel_2: 0.6247 (0.6398)  loss_ce_3: 0.4490 (0.4446)  loss_bbox_3: 0.9403 (1.0196)  loss_giou_3: 1.0132 (1.0763)  loss_rel_3: 0.5093 (0.6449)  loss_ce_4: 0.4499 (0.4430)  loss_bbox_4: 0.9925 (1.0126)  loss_giou_4: 0.9407 (1.0624)  loss_rel_4: 0.5286 (0.6496)  loss_ce_unscaled: 0.4340 (0.4400)  class_error_unscaled: 42.8571 (33.4785)  sub_error_unscaled: 66.6667 (53.8067)  obj_error_unscaled: 42.8571 (50.4172)  loss_bbox_unscaled: 0.1895 (0.2024)  loss_giou_unscaled: 0.4719 (0.5297)  cardinality_error_unscaled: 9.0000 (6.9053)  loss_rel_unscaled: 0.5983 (0.6604)  rel_error_unscaled: 71.4286 (67.2519)  loss_ce_0_unscaled: 0.4742 (0.4815)  loss_bbox_0_unscaled: 0.2129 (0.2278)  loss_giou_0_unscaled: 0.5495 (0.6036)  cardinality_error_0_unscaled: 8.0000 (7.5408)  loss_rel_0_unscaled: 0.5613 (0.6407)  loss_ce_1_unscaled: 0.4517 (0.4623)  loss_bbox_1_unscaled: 0.1723 (0.2138)  loss_giou_1_unscaled: 0.5096 (0.5628)  cardinality_error_1_unscaled: 8.0000 (7.0957)  loss_rel_1_unscaled: 0.5601 (0.6393)  loss_ce_2_unscaled: 0.4470 (0.4509)  loss_bbox_2_unscaled: 0.1863 (0.2075)  loss_giou_2_unscaled: 0.5460 (0.5475)  cardinality_error_2_unscaled: 7.0000 (6.8806)  loss_rel_2_unscaled: 0.6247 (0.6398)  loss_ce_3_unscaled: 0.4490 (0.4446)  loss_bbox_3_unscaled: 0.1881 (0.2039)  loss_giou_3_unscaled: 0.5066 (0.5382)  cardinality_error_3_unscaled: 7.0000 (6.8064)  loss_rel_3_unscaled: 0.5093 (0.6449)  loss_ce_4_unscaled: 0.4499 (0.4430)  loss_bbox_4_unscaled: 0.1985 (0.2025)  loss_giou_4_unscaled: 0.4704 (0.5312)  cardinality_error_4_unscaled: 7.0000 (6.6370)  loss_rel_4_unscaled: 0.5286 (0.6496)  time: 0.2247  data: 0.0158  max mem: 1284
# ...
# Test:  [2900/2919]  eta: 0:00:04  class_error: 27.78  sub_error: 60.00  obj_error: 40.00  rel_error: 60.00  loss: 18.9955 (19.0825)  loss_ce: 0.4600 (0.4268)  loss_bbox: 0.9656 (0.9975)  loss_giou: 1.0314 (1.0508)  loss_rel: 0.4443 (0.6278)  loss_ce_0: 0.4619 (0.4671)  loss_bbox_0: 1.1214 (1.1206)  loss_giou_0: 1.1727 (1.1938)  loss_rel_0: 0.4863 (0.6074)  loss_ce_1: 0.4524 (0.4490)  loss_bbox_1: 1.0501 (1.0517)  loss_giou_1: 1.1768 (1.1133)  loss_rel_1: 0.4748 (0.6071)  loss_ce_2: 0.4312 (0.4375)  loss_bbox_2: 1.0006 (1.0230)  loss_giou_2: 1.1276 (1.0842)  loss_rel_2: 0.4499 (0.6085)  loss_ce_3: 0.4404 (0.4313)  loss_bbox_3: 1.0020 (1.0059)  loss_giou_3: 1.1118 (1.0668)  loss_rel_3: 0.4239 (0.6126)  loss_ce_4: 0.4440 (0.4291)  loss_bbox_4: 0.9681 (0.9994)  loss_giou_4: 1.1528 (1.0548)  loss_rel_4: 0.4276 (0.6165)  loss_ce_unscaled: 0.4600 (0.4268)  class_error_unscaled: 42.1053 (33.3555)  sub_error_unscaled: 75.0000 (53.4899)  obj_error_unscaled: 40.0000 (48.9684)  loss_bbox_unscaled: 0.1931 (0.1995)  loss_giou_unscaled: 0.5157 (0.5254)  cardinality_error_unscaled: 7.0000 (7.2461)  loss_rel_unscaled: 0.4443 (0.6278)  rel_error_unscaled: 100.0000 (66.4510)  loss_ce_0_unscaled: 0.4619 (0.4671)  loss_bbox_0_unscaled: 0.2243 (0.2241)  loss_giou_0_unscaled: 0.5864 (0.5969)  cardinality_error_0_unscaled: 6.0000 (7.9497)  loss_rel_0_unscaled: 0.4863 (0.6074)  loss_ce_1_unscaled: 0.4524 (0.4490)  loss_bbox_1_unscaled: 0.2100 (0.2103)  loss_giou_1_unscaled: 0.5884 (0.5567)  cardinality_error_1_unscaled: 7.0000 (7.4140)  loss_rel_1_unscaled: 0.4748 (0.6071)  loss_ce_2_unscaled: 0.4312 (0.4375)  loss_bbox_2_unscaled: 0.2001 (0.2046)  loss_giou_2_unscaled: 0.5638 (0.5421)  cardinality_error_2_unscaled: 6.0000 (7.2554)  loss_rel_2_unscaled: 0.4499 (0.6085)  loss_ce_3_unscaled: 0.4404 (0.4313)  loss_bbox_3_unscaled: 0.2004 (0.2012)  loss_giou_3_unscaled: 0.5559 (0.5334)  cardinality_error_3_unscaled: 7.0000 (7.1331)  loss_rel_3_unscaled: 0.4239 (0.6126)  loss_ce_4_unscaled: 0.4440 (0.4291)  loss_bbox_4_unscaled: 0.1936 (0.1999)  loss_giou_4_unscaled: 0.5764 (0.5274)  cardinality_error_4_unscaled: 7.0000 (6.9314)  loss_rel_4_unscaled: 0.4276 (0.6165)  time: 0.2417  data: 0.0713  max mem: 1285
# Test:  [2918/2919]  eta: 0:00:00  class_error: 23.08  sub_error: 100.00  obj_error: 0.00  rel_error: 0.00  loss: 17.4892 (19.0719)  loss_ce: 0.3586 (0.4265)  loss_bbox: 0.7063 (0.9970)  loss_giou: 1.0667 (1.0506)  loss_rel: 0.4528 (0.6267)  loss_ce_0: 0.3884 (0.4669)  loss_bbox_0: 0.8519 (1.1200)  loss_giou_0: 1.2398 (1.1937)  loss_rel_0: 0.4345 (0.6065)  loss_ce_1: 0.3536 (0.4487)  loss_bbox_1: 0.8819 (1.0512)  loss_giou_1: 1.1533 (1.1132)  loss_rel_1: 0.4636 (0.6062)  loss_ce_2: 0.3611 (0.4373)  loss_bbox_2: 0.8525 (1.0225)  loss_giou_2: 1.0753 (1.0841)  loss_rel_2: 0.4121 (0.6075)  loss_ce_3: 0.3535 (0.4310)  loss_bbox_3: 0.7686 (1.0054)  loss_giou_3: 1.0844 (1.0666)  loss_rel_3: 0.4045 (0.6117)  loss_ce_4: 0.3679 (0.4289)  loss_bbox_4: 0.8625 (0.9993)  loss_giou_4: 1.0461 (1.0547)  loss_rel_4: 0.4251 (0.6156)  loss_ce_unscaled: 0.3586 (0.4265)  class_error_unscaled: 27.7778 (33.3336)  sub_error_unscaled: 22.2222 (53.3708)  obj_error_unscaled: 14.2857 (48.8428)  loss_bbox_unscaled: 0.1413 (0.1994)  loss_giou_unscaled: 0.5334 (0.5253)  cardinality_error_unscaled: 8.0000 (7.2566)  loss_rel_unscaled: 0.4528 (0.6267)  rel_error_unscaled: 60.0000 (66.3925)  loss_ce_0_unscaled: 0.3884 (0.4669)  loss_bbox_0_unscaled: 0.1704 (0.2240)  loss_giou_0_unscaled: 0.6199 (0.5969)  cardinality_error_0_unscaled: 9.0000 (7.9606)  loss_rel_0_unscaled: 0.4345 (0.6065)  loss_ce_1_unscaled: 0.3536 (0.4487)  loss_bbox_1_unscaled: 0.1764 (0.2102)  loss_giou_1_unscaled: 0.5766 (0.5566)  cardinality_error_1_unscaled: 9.0000 (7.4262)  loss_rel_1_unscaled: 0.4636 (0.6062)  loss_ce_2_unscaled: 0.3611 (0.4373)  loss_bbox_2_unscaled: 0.1705 (0.2045)  loss_giou_2_unscaled: 0.5377 (0.5420)  cardinality_error_2_unscaled: 7.0000 (7.2686)  loss_rel_2_unscaled: 0.4121 (0.6075)  loss_ce_3_unscaled: 0.3535 (0.4310)  loss_bbox_3_unscaled: 0.1537 (0.2011)  loss_giou_3_unscaled: 0.5422 (0.5333)  cardinality_error_3_unscaled: 8.0000 (7.1425)  loss_rel_3_unscaled: 0.4045 (0.6117)  loss_ce_4_unscaled: 0.3679 (0.4289)  loss_bbox_4_unscaled: 0.1725 (0.1999)  loss_giou_4_unscaled: 0.5231 (0.5274)  cardinality_error_4_unscaled: 7.0000 (6.9448)  loss_rel_4_unscaled: 0.4251 (0.6156)  time: 0.2719  data: 0.0825  max mem: 1285
# Test: Total time: 0:12:38 (0.2597 s / it)
# ======================sgdet============================
# R@20: 0.196249
# R@50: 0.243019
# R@100: 0.267260
#
#
# relationship:  above
# ======================sgdet============================
# R@20: 0.070667
# R@50: 0.094667
# R@100: 0.110667
#
#
# relationship:  across
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  against
# ======================sgdet============================
# R@20: 0.100000
# R@50: 0.100000
# R@100: 0.100000
#
#
# relationship:  along
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  and
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  at
# ======================sgdet============================
# R@20: 0.142248
# R@50: 0.172093
# R@100: 0.176744
#
#
# relationship:  attached to
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  behind
# ======================sgdet============================
# R@20: 0.116782
# R@50: 0.186227
# R@100: 0.212539
#
#
# relationship:  belonging to
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  between
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  carrying
# ======================sgdet============================
# R@20: 0.110215
# R@50: 0.110215
# R@100: 0.115591
#
#
# relationship:  covered in
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  covering
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  eating
# ======================sgdet============================
# R@20: 0.156250
# R@50: 0.156250
# R@100: 0.156250
#
#
# relationship:  flying in
# ======================sgdet============================
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# R@20: nan
# R@50: nan
# R@100: nan
#
#
# relationship:  for
# ======================sgdet============================
# R@20: 0.044444
# R@50: 0.044444
# R@100: 0.066667
#
#
# relationship:  from
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  growing on
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  hanging from
# ======================sgdet============================
# R@20: 0.052632
# R@50: 0.052632
# R@100: 0.052632
#
#
# relationship:  has
# ======================sgdet============================
# R@20: 0.253088
# R@50: 0.307476
# R@100: 0.329149
#
#
# relationship:  holding
# ======================sgdet============================
# R@20: 0.213725
# R@50: 0.246233
# R@100: 0.268937
#
#
# relationship:  in
# ======================sgdet============================
# R@20: 0.078643
# R@50: 0.147811
# R@100: 0.175194
#
#
# relationship:  in front of
# ======================sgdet============================
# R@20: 0.039370
# R@50: 0.057743
# R@100: 0.085302
#
#
# relationship:  laying on
# ======================sgdet============================
# R@20: 0.096154
# R@50: 0.096154
# R@100: 0.096154
#
#
# relationship:  looking at
# ======================sgdet============================
# R@20: 0.064516
# R@50: 0.096774
# R@100: 0.096774
#
#
# relationship:  lying on
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  made of
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  mounted on
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  near
# ======================sgdet============================
# R@20: 0.099254
# R@50: 0.155877
# R@100: 0.188200
#
#
# relationship:  of
# ======================sgdet============================
# R@20: 0.205086
# R@50: 0.260550
# R@100: 0.283536
#
#
# relationship:  on
# ======================sgdet============================
# R@20: 0.231097
# R@50: 0.284069
# R@100: 0.314730
#
#
# relationship:  on back of
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  over
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.017857
#
#
# relationship:  painted on
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  parked on
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.166667
# R@100: 0.166667
#
#
# relationship:  part of
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  playing
# ======================sgdet============================
# R@20: nan
# R@50: nan
# R@100: nan
#
#
# relationship:  riding
# ======================sgdet============================
# R@20: 0.252874
# R@50: 0.295019
# R@100: 0.295019
#
#
# relationship:  says
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  sitting on
# ======================sgdet============================
# R@20: 0.071839
# R@50: 0.142720
# R@100: 0.194444
#
#
# relationship:  standing on
# ======================sgdet============================
# R@20: 0.030000
# R@50: 0.076667
# R@100: 0.093333
#
#
# relationship:  to
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  under
# ======================sgdet============================
# R@20: 0.081275
# R@50: 0.122451
# R@100: 0.134216
#
#
# relationship:  using
# ======================sgdet============================
# R@20: 0.138889
# R@50: 0.138889
# R@100: 0.138889
#
#
# relationship:  walking in
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.000000
# R@100: 0.000000
#
#
# relationship:  walking on
# ======================sgdet============================
# R@20: 0.038462
# R@50: 0.094872
# R@100: 0.094872
#
#
# relationship:  watching
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.012245
# R@100: 0.019388
#
#
# relationship:  wearing
# ======================sgdet============================
# R@20: 0.351190
# R@50: 0.387278
# R@100: 0.396974
#
#
# relationship:  wears
# ======================sgdet============================
# R@20: 0.000000
# R@50: 0.013584
# R@100: 0.027952
#
#
# relationship:  with
# ======================sgdet============================
# R@20: 0.038196
# R@50: 0.062679
# R@100: 0.074672
#
#
# ======================sgdet  mean recall with constraint============================
# mR@20:  0.06153789524341029
# mR@50:  0.0816456953612808
# mR@100:  0.08966694481124313
# Averaged stats: class_error: 23.08  sub_error: 100.00  obj_error: 0.00  rel_error: 0.00  loss: 17.4892 (19.0719)  loss_ce: 0.3586 (0.4265)  loss_bbox: 0.7063 (0.9970)  loss_giou: 1.0667 (1.0506)  loss_rel: 0.4528 (0.6267)  loss_ce_0: 0.3884 (0.4669)  loss_bbox_0: 0.8519 (1.1200)  loss_giou_0: 1.2398 (1.1937)  loss_rel_0: 0.4345 (0.6065)  loss_ce_1: 0.3536 (0.4487)  loss_bbox_1: 0.8819 (1.0512)  loss_giou_1: 1.1533 (1.1132)  loss_rel_1: 0.4636 (0.6062)  loss_ce_2: 0.3611 (0.4373)  loss_bbox_2: 0.8525 (1.0225)  loss_giou_2: 1.0753 (1.0841)  loss_rel_2: 0.4121 (0.6075)  loss_ce_3: 0.3535 (0.4310)  loss_bbox_3: 0.7686 (1.0054)  loss_giou_3: 1.0844 (1.0666)  loss_rel_3: 0.4045 (0.6117)  loss_ce_4: 0.3679 (0.4289)  loss_bbox_4: 0.8625 (0.9993)  loss_giou_4: 1.0461 (1.0547)  loss_rel_4: 0.4251 (0.6156)  loss_ce_unscaled: 0.3586 (0.4265)  class_error_unscaled: 27.7778 (33.3336)  sub_error_unscaled: 22.2222 (53.3708)  obj_error_unscaled: 14.2857 (48.8428)  loss_bbox_unscaled: 0.1413 (0.1994)  loss_giou_unscaled: 0.5334 (0.5253)  cardinality_error_unscaled: 8.0000 (7.2566)  loss_rel_unscaled: 0.4528 (0.6267)  rel_error_unscaled: 60.0000 (66.3925)  loss_ce_0_unscaled: 0.3884 (0.4669)  loss_bbox_0_unscaled: 0.1704 (0.2240)  loss_giou_0_unscaled: 0.6199 (0.5969)  cardinality_error_0_unscaled: 9.0000 (7.9606)  loss_rel_0_unscaled: 0.4345 (0.6065)  loss_ce_1_unscaled: 0.3536 (0.4487)  loss_bbox_1_unscaled: 0.1764 (0.2102)  loss_giou_1_unscaled: 0.5766 (0.5566)  cardinality_error_1_unscaled: 9.0000 (7.4262)  loss_rel_1_unscaled: 0.4636 (0.6062)  loss_ce_2_unscaled: 0.3611 (0.4373)  loss_bbox_2_unscaled: 0.1705 (0.2045)  loss_giou_2_unscaled: 0.5377 (0.5420)  cardinality_error_2_unscaled: 7.0000 (7.2686)  loss_rel_2_unscaled: 0.4121 (0.6075)  loss_ce_3_unscaled: 0.3535 (0.4310)  loss_bbox_3_unscaled: 0.1537 (0.2011)  loss_giou_3_unscaled: 0.5422 (0.5333)  cardinality_error_3_unscaled: 8.0000 (7.1425)  loss_rel_3_unscaled: 0.4045 (0.6117)  loss_ce_4_unscaled: 0.3679 (0.4289)  loss_bbox_4_unscaled: 0.1725 (0.1999)  loss_giou_4_unscaled: 0.5231 (0.5274)  cardinality_error_4_unscaled: 7.0000 (6.9448)  loss_rel_4_unscaled: 0.4251 (0.6156)
# Accumulating evaluation results...
# DONE (t=11.14s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.131
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.276
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.400

# %% [markdown]
# #Inference Example

# %%
CLASSES = [ 'N/A', 'airplane', 'animal', 'arm', 'bag', 'banana', 'basket', 'beach', 'bear', 'bed', 'bench', 'bike',
                'bird', 'board', 'boat', 'book', 'boot', 'bottle', 'bowl', 'box', 'boy', 'branch', 'building',
                'bus', 'cabinet', 'cap', 'car', 'cat', 'chair', 'child', 'clock', 'coat', 'counter', 'cow', 'cup',
                'curtain', 'desk', 'dog', 'door', 'drawer', 'ear', 'elephant', 'engine', 'eye', 'face', 'fence',
                'finger', 'flag', 'flower', 'food', 'fork', 'fruit', 'giraffe', 'girl', 'glass', 'glove', 'guy',
                'hair', 'hand', 'handle', 'hat', 'head', 'helmet', 'hill', 'horse', 'house', 'jacket', 'jean',
                'kid', 'kite', 'lady', 'lamp', 'laptop', 'leaf', 'leg', 'letter', 'light', 'logo', 'man', 'men',
                'motorcycle', 'mountain', 'mouth', 'neck', 'nose', 'number', 'orange', 'pant', 'paper', 'paw',
                'people', 'person', 'phone', 'pillow', 'pizza', 'plane', 'plant', 'plate', 'player', 'pole', 'post',
                'pot', 'racket', 'railing', 'rock', 'roof', 'room', 'screen', 'seat', 'sheep', 'shelf', 'shirt',
                'shoe', 'short', 'sidewalk', 'sign', 'sink', 'skateboard', 'ski', 'skier', 'sneaker', 'snow',
                'sock', 'stand', 'street', 'surfboard', 'table', 'tail', 'tie', 'tile', 'tire', 'toilet', 'towel',
                'tower', 'track', 'train', 'tree', 'truck', 'trunk', 'umbrella', 'vase', 'vegetable', 'vehicle',
                'wave', 'wheel', 'window', 'windshield', 'wing', 'wire', 'woman', 'zebra']

REL_CLASSES = ['__background__', 'above', 'across', 'against', 'along', 'and', 'at', 'attached to', 'behind',
                'belonging to', 'between', 'carrying', 'covered in', 'covering', 'eating', 'flying in', 'for',
                'from', 'growing on', 'hanging from', 'has', 'holding', 'in', 'in front of', 'laying on',
                'looking at', 'lying on', 'made of', 'mounted on', 'near', 'of', 'on', 'on back of', 'over',
                'painted on', 'parked on', 'part of', 'playing', 'riding', 'says', 'sitting on', 'standing on',
                'to', 'under', 'using', 'walking in', 'walking on', 'watching', 'wearing', 'wears', 'with']

# %%
from models.backbone import Backbone, Joiner
from models.position_encoding import PositionEmbeddingSine
from models.transformer import Transformer
from models.reltr import RelTR

position_embedding = PositionEmbeddingSine(128, normalize=True)
backbone = Backbone('resnet50', False, False, False)
backbone = Joiner(backbone, position_embedding)
backbone.num_channels = 2048

transformer = Transformer(d_model=256, dropout=0.1, nhead=8,
                          dim_feedforward=2048,
                          num_encoder_layers=6,
                          num_decoder_layers=6,
                          normalize_before=False,
                          return_intermediate_dec=True)

model = RelTR(backbone, transformer, num_classes=151, num_rel_classes = 51,
              num_entities=100, num_triplets=200)

# The checkpoint is pretrained on Visual Genome
ckpt = torch.load('ckpt/checkpoint0149.pth')
model.load_state_dict(ckpt['model'])
model.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <ipython-input-6-7cd65e5d217f>:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load('ckpt/checkpoint0149.pth')
# RelTR(
#   (transformer): Transformer(
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-5): 6 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (decoder): TransformerDecoder(
#       (layers): ModuleList(
#         (0-5): 6 x TransformerDecoderLayer(
#           (self_attn_entity): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout2_entity): Dropout(p=0.1, inplace=False)
#           (norm2_entity): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_entity): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout1_entity): Dropout(p=0.1, inplace=False)
#           (norm1_entity): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (self_attn_so): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout2_so): Dropout(p=0.1, inplace=False)
#           (norm2_so): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_sub): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout1_sub): Dropout(p=0.1, inplace=False)
#           (norm1_sub): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_sub_entity): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout2_sub): Dropout(p=0.1, inplace=False)
#           (norm2_sub): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_obj): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout1_obj): Dropout(p=0.1, inplace=False)
#           (norm1_obj): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_obj_entity): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout2_obj): Dropout(p=0.1, inplace=False)
#           (norm2_obj): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (linear1_entity): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout3_entity): Dropout(p=0.1, inplace=False)
#           (linear2_entity): Linear(in_features=2048, out_features=256, bias=True)
#           (dropout4_entity): Dropout(p=0.1, inplace=False)
#           (norm3_entity): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (linear1_sub): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout3_sub): Dropout(p=0.1, inplace=False)
#           (linear2_sub): Linear(in_features=2048, out_features=256, bias=True)
#           (dropout4_sub): Dropout(p=0.1, inplace=False)
#           (norm3_sub): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (linear1_obj): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout3_obj): Dropout(p=0.1, inplace=False)
#           (linear2_obj): Linear(in_features=2048, out_features=256, bias=True)
#           (dropout4_obj): Dropout(p=0.1, inplace=False)
#           (norm3_obj): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (input_proj): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#   (backbone): Joiner(
#     (0): Backbone(
#       (body): IntermediateLayerGetter(
#         (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (bn1): FrozenBatchNorm2d()
#         (relu): ReLU(inplace=True)
#         (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer2): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (3): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer3): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (3): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (4): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (5): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer4): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (1): PositionEmbeddingSine()
#   )
#   (entity_embed): Embedding(100, 512)
#   (triplet_embed): Embedding(200, 768)
#   (so_embed): Embedding(2, 256)
#   (entity_class_embed): Linear(in_features=256, out_features=152, bias=True)
#   (entity_bbox_embed): MLP(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#       (2): Linear(in_features=256, out_features=4, bias=True)
#     )
#   )
#   (so_mask_conv): Sequential(
#     (0): Upsample(size=(28, 28), mode='nearest')
#     (1): Conv2d(2, 64, kernel_size=(3, 3), stride=(2, 2), padding=(3, 3))
#     (2): ReLU(inplace=True)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (so_mask_fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=128, bias=True)
#   )
#   (rel_class_embed): MLP(
#     (layers): ModuleList(
#       (0): Linear(in_features=640, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=52, bias=True)
#     )
#   )
#   (sub_class_embed): Linear(in_features=256, out_features=152, bias=True)
#   (sub_bbox_embed): MLP(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#       (2): Linear(in_features=256, out_features=4, bias=True)
#     )
#   )
#   (obj_class_embed): Linear(in_features=256, out_features=152, bias=True)
#   (obj_bbox_embed): MLP(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#       (2): Linear(in_features=256, out_features=4, bias=True)
#     )
#   )
# )

# %%
# Some transformation functions
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
          (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
img_path = 'demo/vg1.jpg'
im = Image.open(img_path)
plt.imshow(im)
img = transform(im).unsqueeze(0)

# %%
# propagate through the model
outputs = model(img)

# keep only predictions with >0.3 confidence
probas = outputs['rel_logits'].softmax(-1)[0, :, :-1]
probas_sub = outputs['sub_logits'].softmax(-1)[0, :, :-1]
probas_obj = outputs['obj_logits'].softmax(-1)[0, :, :-1]
keep = torch.logical_and(probas.max(-1).values > 0.3, torch.logical_and(probas_sub.max(-1).values > 0.3,
                                                                        probas_obj.max(-1).values > 0.3))

# %%
# convert boxes from [0; 1] to image scales
sub_bboxes_scaled = rescale_bboxes(outputs['sub_boxes'][0, keep], im.size)
obj_bboxes_scaled = rescale_bboxes(outputs['obj_boxes'][0, keep], im.size)

topk = 10 # display up to 10 images
keep_queries = torch.nonzero(keep, as_tuple=True)[0]
indices = torch.argsort(-probas[keep_queries].max(-1)[0] * probas_sub[keep_queries].max(-1)[0] * probas_obj[keep_queries].max(-1)[0])[:topk]
keep_queries = keep_queries[indices]

# %%
# save the attention weights
conv_features, dec_attn_weights_sub, dec_attn_weights_obj = [], [], []
hooks = [
    model.backbone[-2].register_forward_hook(
        lambda self, input, output: conv_features.append(output)
    ),
    model.transformer.decoder.layers[-1].cross_attn_sub.register_forward_hook(
        lambda self, input, output: dec_attn_weights_sub.append(output[1])
    ),
    model.transformer.decoder.layers[-1].cross_attn_obj.register_forward_hook(
        lambda self, input, output: dec_attn_weights_obj.append(output[1])
    )]

# %%
with torch.no_grad():
    # propagate through the model
    outputs = model(img)

    for hook in hooks:
        hook.remove()

    # don't need the list anymore
    conv_features = conv_features[0]
    dec_attn_weights_sub = dec_attn_weights_sub[0]
    dec_attn_weights_obj = dec_attn_weights_obj[0]

    # get the feature map shape
    h, w = conv_features['0'].tensors.shape[-2:]
    im_w, im_h = im.size

    fig, axs = plt.subplots(ncols=len(indices), nrows=3, figsize=(22, 7))
    for idx, ax_i, (sxmin, symin, sxmax, symax), (oxmin, oymin, oxmax, oymax) in \
            zip(keep_queries, axs.T, sub_bboxes_scaled[indices], obj_bboxes_scaled[indices]):
        ax = ax_i[0]
        ax.imshow(dec_attn_weights_sub[0, idx].view(h, w))
        ax.axis('off')
        ax.set_title(f'query id: {idx.item()}')
        ax = ax_i[1]
        ax.imshow(dec_attn_weights_obj[0, idx].view(h, w))
        ax.axis('off')
        ax = ax_i[2]
        ax.imshow(im)
        ax.add_patch(plt.Rectangle((sxmin, symin), sxmax - sxmin, symax - symin,
                                    fill=False, color='blue', linewidth=2.5))
        ax.add_patch(plt.Rectangle((oxmin, oymin), oxmax - oxmin, oymax - oymin,
                                    fill=False, color='orange', linewidth=2.5))

        ax.axis('off')
        ax.set_title(CLASSES[probas_sub[idx].argmax()]+' '+REL_CLASSES[probas[idx].argmax()]+' '+CLASSES[probas_obj[idx].argmax()], fontsize=10)

    fig.tight_layout()
    plt.show() # show the output
